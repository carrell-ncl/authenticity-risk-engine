# %%
from sort_audio_data import organise_audio_by_protocol

get_set = 'eval'

source_audio_dir = f'/Users/stevencarrell/Downloads/LA/ASVspoof2019_LA_{get_set}/flac'
protacol_file = f'/Users/stevencarrell/Downloads/LA/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.{get_set}.trl.txt'

# %%
summary = organise_audio_by_protocol(
    source_audio_dir=source_audio_dir,
    protocol_file=protacol_file,
    target_root_dir=f"../data/audio/{get_set}",
    move=False  # start with copy to be safe
)

print(summary)
# Out:
# {'real': 7355, 'fake': 63882, 'missing': [], 'total_protocol_entries': 71237}

# %%
import os 
os.getcwd()
# Out:
# '/Users/stevencarrell/Desktop/dev/authenticity-risk-engine/utils'
