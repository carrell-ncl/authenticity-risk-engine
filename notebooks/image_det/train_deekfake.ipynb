# %%
import os 

os.chdir('../..')

# %%
# Out:
# 'c:\\Users\\Steve\\Desktop\\dev\\authenticity-risk-engine'

# %%
# %run src/image_det/train/train_deepfake.py --data_dir "src/image_det/data/processed" --epochs 10 --batch_size 32
